# %% [markdown]
# <a href="https://colab.research.google.com/github/vixiv0418/Oss2025/blob/main/API_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Youtube API와 함께하는 핸즈온 튜토리얼
# Youtube는 No1인 비디오 공유 플랫폼이다. 1억명 사용자들은 수천억시간의 비디오를 소비하고 매분마다 500시간의 컨텐츠가 업로드된다.
#
# 다양한 형태와 장르의 영상들이 존재한다. 주로 뮤직비디오, 강좌, 버라이어티 쇼, 드라마, 상품 리뷰 등 녹화된 방송들이 게시되기도 한다. 한편, 홈쇼핑, 게이밍 대회 와 같은 영상들은 실시간으로 스트리밍 되기도 한다.
#
# 빅데이터 4V(Volume, Velocity, Variety, Veracity) 측면에서 Youtube 관련 데이터를 관심있어야하는 이유는 다음과 같다.
# - Volume: 10억명의 사용자가 생성하고 관람하는 데이터는 엄청나게 많다.
# - Velocity: 다양한 스트리밍 채널에서 사용자들은 수초내에 수백개의 메시지와 함께 커뮤니케이션 및 보기가 가능하다.
# - Variety: 동영상 데이터 뿐만 아니라, 구조화된  데이터(통계치, 메타데이터)와 비구조화된 텍스트(채팅, 댓글)들을 다룰 수 있다.
# - Veracity: Youtube 영상 자체가 특정 사실에 대해 불확실 정보를 포함할 수 있으며, 영상에 대한 정보가 잘못 표기될 수도 있다.

# %% [markdown]
# # 본 튜토리얼의 기본 목표
# 1. Youtube API를 이용하여 영상을 검색하거나 관련된 정보를 수집할 수 있다.
# 2. 수집된 정보로부터 그래프 기반 시각화
# 3. 키워드 분석

# %% [markdown]
# Copyright 2023 by datasciencelabs.org

# %% [markdown]
# # 사전조건
# 1. Youtube API를 활용하기 위해서는 Google API Python Client Library.로부터 API Key를 발급받아야 한다.
# 2. 개인 컴퓨터를 사용하는 경우, 가능한 Linux를 이용해서 설치(install)부분을 설치완료해야한다.

# %% [markdown]
# # 설치하기

# %% [markdown]
# install the google api python client

# %%
# !pip install google-api-python-client youtube_transcript_api
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.164.0)
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2025.1.31)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)

# %% [markdown]
# # API documentation
# 구체적인 Youtube API[https://developers.google.com/youtube/v3] 다음 링크에 있는 문서를 참고하시기 바랍니다.
#
# API Reference
# https://developers.google.com/youtube/v3/docs

# %% [markdown]
# ## Query Template
#
# PYTHON API는 다음과 같이 api.(resources).(method) 형태로 구성된다.
# ```
# # To perform list method on playlists resource
# request = youtube.playlists().list(
# )
# # To perform list method on videos resource
# request = youtube.videos().list(
# )
# # to perform list method on channels resource
# request = youtube.channels().list(
# )
# ```

# %% [markdown]
# Search vs. Video resources
#
# Search resource: contains information about a Youtube video, channel or playlist that matches the search parameters specified in an API request
#
# Video resource: representes a Youtube Video

# %% [markdown]
# Part parameter
# https://developers.google.com/youtube/v3/docs/search/list#parameters
#
# a comma-separated list of one or more search resource properties that the API response will include. Set the parameter value to snippet.

# %%
# API client library
import googleapiclient.discovery
# API information
api_service_name = "youtube"
api_version = "v3"
API_KEY = "AIzaSyB8D22GCcbAOKBlBIscbVB7Omh5S0FYfnU"

# API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = API_KEY)

# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
# in your query
request = youtube.search().list(
    part="id,snippet",
    type='video',
    q="C++ 강의",
    videoDuration='medium',
    videoDefinition='high',
    maxResults= 5
)

# Query execution
video_list = request.execute()

# Print the results
video_list
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'tv8UK15K8axts3Iu54REpKlvH-4',
#  'nextPageToken': 'CAUQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'ZW0nwgdk_RkdSogZYoVbRk5WAks',
#    'id': {'kind': 'youtube#video', 'videoId': 'k6HPjMyVJy0'},
#    'snippet': {'publishedAt': '2021-10-16T10:47:11Z',
#     'channelId': 'UCBtG00ljZ8R_DBQCTR4C00A',
#     'title': '개발자로의 기로에 서게 했던 ... C언어 포인터 문제 (from 정보처리기사 정처기 문제)',
#     'description': '정보처리기사#정처기#C언어#포인터 c언어 체계적인 학습을 위한 강의 영상을 준비했습니다. https://inf.run/69FUG 도움이 되셨다면 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/k6HPjMyVJy0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/k6HPjMyVJy0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/k6HPjMyVJy0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '기술노트with 알렉',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-16T10:47:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'C08HenNQ_ShKs-6vs8XiGr9n4cE',
#    'id': {'kind': 'youtube#video', 'videoId': 'zGrTT4k1-yc'},
#    'snippet': {'publishedAt': '2019-10-07T07:54:05Z',
#     'channelId': 'UCUpJs89fSBXNolQGOYKn0YQ',
#     'title': 'C. C++. C#. 차이점 알려드림. 5분 순삭.',
#     'description': '업데이트가 늦었습니다 ㅠㅠㅠ (결혼 축하해주신 분들 너무 고맙습니다! ;)) 오늘도 코린이. 코알못을 위한 영상을 들고 왔어요! 아시죠?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zGrTT4k1-yc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zGrTT4k1-yc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zGrTT4k1-yc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '노마드 코더 Nomad Coders',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-10-07T07:54:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FOrWFldfmUrGQxsZKLZDXY-OZqU',
#    'id': {'kind': 'youtube#video', 'videoId': 'UwUeTqBRjY0'},
#    'snippet': {'publishedAt': '2022-12-29T11:00:30Z',
#     'channelId': 'UChu25pJgVZB3p0dVEgmU0PQ',
#     'title': 'C언어. C++ 아직도 헷갈리세요?ㅣ7년차 코딩강사 개념강의',
#     'description': 'c언어 #C++ #코딩 #개발자 C언어와 C++ 개념차이가 궁금하다면 7년차 코딩강사 선생님이 알려드림 [강사이력] (전) 대치동 씨큐브 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UwUeTqBRjY0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UwUeTqBRjY0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UwUeTqBRjY0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '메타코드M',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-29T11:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XnbDqw_LYbAUGLQP1N0Ohew-XGc',
#    'id': {'kind': 'youtube#video', 'videoId': 'iIQXlLv_yHI'},
#    'snippet': {'publishedAt': '2016-08-03T15:42:26Z',
#     'channelId': 'UCmGcqqKdIKnH_-oHnkoyshg',
#     'title': '[C/C++ 강좌] 54강. 클래스 = 구조체??',
#     'description': 'C++의 중요한 기능인 클래스의 개념을 파악해보자. 질문 있으시면 댓글에 남겨주세요.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iIQXlLv_yHI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iIQXlLv_yHI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iIQXlLv_yHI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '두들낙서',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-08-03T15:42:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JwZhug3TfBAC27v3Ca017fzSUBw',
#    'id': {'kind': 'youtube#video', 'videoId': 'vr-rClhJpF8'},
#    'snippet': {'publishedAt': '2023-04-30T13:00:41Z',
#     'channelId': 'UCoN1XLeAX2OazuZdQ9b8U9Q',
#     'title': 'C++ 10주완성 코딩테스트 강의 소개',
#     'description': 'CS지식의 정석 https://inf.run/17Fb ▷C++ 10주완성 코딩테스트 https://inf.run/xZhA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vr-rClhJpF8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vr-rClhJpF8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vr-rClhJpF8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '큰돌의터전',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-30T13:00:41Z'}}]}

# %%
videoId1 = video_list['items'][0]['id']['videoId']
videoId2 = video_list['items'][1]['id']['videoId']
videoId3 = video_list['items'][2]['id']['videoId']
videoId4 = video_list['items'][3]['id']['videoId']
videoId5 = video_list['items'][4]['id']['videoId']

# %% [markdown]
# ### Youtube 자막 받아오기

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Youtube 자막 추출 함수
def get_transcript(video_id, languages=['ko']):
  transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko'])
  full_transcript = ' '.join([item['text'] for item in transcript])
  return full_transcript

# %%
# Video ID 추출
video_id = video_list['items'][0]['id']['videoId']

# Youtube 영상의 자막 받아오기
full_transcript1 = get_transcript(videoId1)
full_transcript3 = get_transcript(videoId3)
full_transcript4 = get_transcript(videoId4)
full_transcript5 = get_transcript(videoId5)

print(full_transcript1)
print(full_transcript3)
print(full_transcript4)
print(full_transcript5)
# Out:
# 자 안녕하세요 오늘 주제는 시언어 포인터에 대한 얘기를 잠깐 드리려고 합니다 자 포인터라고 하고 자 요런 표현을 쓰기도 하고요 어 이렇게도 표현을 합니다 자 이거만 딱 이해하시면 끝납니다 그 변수라는 것을 변수라는 것은 어떤 값이든 저장할 수 있는 개념의 장소 변수라는게 자 인트는 x 아고 정의할 수 있어요 그리고 x 값에 어 10이라고 입력할 수 있습니다 그리고 그러면 x 값은 어 10에 여기까지 무리 없죠 가능합니다 자 그러면 변수 값이라는 것은 어떤 숫자값 인트 일 때는 숫자값을 저장하는 역할하고이 변수 x n x 아는 것은 어 10을 가지고 있다라고 표현할 수가 있고 다시 말해서 요런 메모리 위치값 값 매 값의 10이 저장돼 있고 어 이것을 x x 어 x 이제 정의를 한 거죠 이렇게 선언을 한 거예요 자 그러면 자 인트 어 p 아는 변수를 하는데 이렇게 했으면 p x 동일한 어 형태의 변수인데 만약에 요렇게 요렇게 같이 어 아스트릭이라고 해서 어 요런 문자를 같이 넣었다 그럼 이게 포인트예요 그때부터 자 그래서 에 렇게 10을 넣는 개념이 아니고 이렇게 넣는게 아니고 PN PN 어이 위에 변수를 변수를 값을 받는다고 할게요 그러면 어떤 식으로 냐면 어 요런 식으로 주소의 x 그래서 무슨 얘기냐는 이제 주소를 관리하는 어 변수인 거고이 주소는 어 요런 식으로 표시를 하는 거예요 주소는 드라고 하죠 퍼센 자 이런 식으로 주소로 표현을 하고 자 p 값이 뭐냐라고 물으면 이건 그냥 주소예요 주소 그래서 알 수가 없어요 자 여기를 가르키는 주소 여기 가르키는 여기를 가르킵니다 여기를 가르쳐요 이렇게 그래서 내용을 꺼내고 싶으면 요렇게 하면은 어 요거는 이제 10이 나오게 됩니다요 개념만 사실 정확히 알고 있으면 되고요 자 또 하나 여기서 연결시켜서 한 가지만 더 얘기를 할게요 자 인트 인트 S 배열이라고 들어보셨죠 3 이렇게 선언을 하면요 자 이거는 어떻게 되냐면 이런 값에 이런 값의 이런 배열이라고 하는데 연속된 어떤 메모리 위치 값에 어 세 칸 인티저 세 개를 저장할 수 있게끔 요렇게 선언이 된 거예요 자 여기서 한 가지 개념만 더하시면 되는데 여기를 요렇게 선언을 하면이 값을 어떻게 하냐면 여기는 x 0부터 시작합니다 0 그리고 s 1 s 2 어 요렇게 값을 찍어낼 수가 있어요 그리고 얘 값을 어 세팅을 할 때 요렇게 해 놓고 뭐 1 2 3 하면 각각이 1 2 3이 됩니다 자 물이 없죠 그런데 얘도 주소로서 가르칠 수가 있어요 여기까지만 딱 이해하시면 되는데 여기 S 0의 주소는 s 자 여기 주소는 s + 1 여기 플스 s + 2 여기까지만 하면 요건 주소예요 주소 주소 그래서 결국 어 이것의 값을 어 가져오려면 요런 식으로 거세 0 하거나 내용의 S 내용에 s + 1 이렇게 하면이 두 번째 위치값을 가져오게 됩니다 자 포인트하고 약간 연결이 되면서도 이제 요런 식으로 가르키고 값을 가져온다까지만 아시면 사실 포인터라는게 뭐 복잡하게 막 투 포인트가 나오고 그러면 이제 복잡해지는데 딱 여기까지만 이해하셔도 어 문제를 풀 수가 있어요 자 정보처리 기사 문제 하나 어 비슷한 유형의 것이 나왔다고 해서 한번 보겠습니다 이런 문제인데요음 그렇게 어렵게 생각하실 건 없고 여기 스트럭처 스트럭쳐는 구조체 해서 언어에서 쓰는데 구조체는 어 이렇게 생각하시면 돼요 그냥 하나의 캐릭터 인티저 이런 식으로 변수를 정의하는데 이런 것들을 같이 포함해서 어 어떤 값을 다루고 싶을 때 이렇게 구조체로 씁니다 예를 들면 여기 보시면 이제 얘가 잘 나오는데이 스튜던트 아는 구조체는 구조체는 이름을 저장할 수 있는 그런 변수 그리고 보니까 이제 코리아 매스 썸 토탈 왠지 어 성적을 관리하는 거 같아요 자 그래서 뭐 국어는 어떻고 수학은 어떻고 하는 값을 어 가치 관리하기 위해서 자 이런 걸 자체 관리하는게 좋을 수 있는게 어 이름 뒤에 홍길동 뒤에 뭐 항상 따라가는 여기에서 지금 관리하려고 하는 점수들이 뭐 어떤 그 성적에 따라 점수 1 점수 2 이렇게 있으면 나중에이 스트럭처 관리가 되면은 이거에 따라서 자연스럽게이 뒤의 값들을 뽑아올 수가 있겠죠 그래서 스트럭처로 관리하면 어 좋은 면이 있습니다 자 스트럭처 아고 선언을 하고 스튜던트 아고 해서 세명을 정의를 했어요 세 개를 자 이름 이렇게 들어가고요 여기 초기값으로 세팅 하는 과정인데 이름 이렇게 들어가고 점수를 각각 이렇게 넣었어요 자 점수를 넣고 어 렇게 넣고 이순신이고 넣고 아무개가 넣죠 이렇게 그러면이 구조체 세 개가 정의된 곳에 값이 요렇게 다 어 처음값 처음값 S 0이죠 s0 그다음에 S1 S2 어 저장이 된 겁니다 그리고 스튜를 가르키는 어 포인트 변수를 하나 어 선언을 한 거예요 그리고 나서 그리고 나서 첫 번째 값에 주소를 넣었어요 결국 포인트인 거죠 주소값을 넣었기 때문에 자 S 0이라고 안 들어갔을 거예요 이건 이미 주소로 정의가 돼 있어요 이렇게 자 주소를 기억해야 되기 때문에 렇게 주소로 넣은 거고요 자 요게 달라요 선언할 땐 요게 포인트고요 자 그 변수 값을 받을 때 요렇게 야 주소가 됩니다 변수값에 어 포인트 p고 했으면 p 렇게 넣어야 이제이 주소로 주소로 해서 p 들어가게 됩니다 자 그러면 여기서 질문이 뭘까 보면은 p + 1의 코리아 그럼 p 여기 첫 번째 주소 첫 번째 주소에 이게 p 그래요 이게 p 이거 p 자체예요 자 P + 1 어디냐 여기입니다 P + 1 여기는 p + 2예요 자 그래서 p + 1의 코리아 자 코리아가 첫 번째 거죠 90 자 p+ 2의 매스 매스는 두 번째 거죠 p+ 2에 아 아 여기 여기는 88 그니까 헷갈려요 자 헷갈리다 거를 얘기했어 플스 1에 코리안 88 여기 88이 88 p+ 2의 매스 여기 p+ 2죠 여기예요 여기 75 75 88 + 75 그가 여기 P1 썸에 넣겠다 자 P1이면 여기에 여기 아직 그 값이 초기화는 안 됐지만 어쨌든 썸이라는 변수가 있죠 섬에다 넣은 거예요 왜 이렇게 넣는지 모르겠지만 하여튼 넣었어요 자 888+ 75에 그러면 자음 3 163 163이구루 응 값을 이게 토이라이더가면라이더제로원 1 0 5 이렇게 되나요 자 한번 어이 프로그램을 한번 돌려보겠습니다 자 요즘 보니까 이렇게 사이트에서도 컴파일이 되네요 자 r c 글이네요 아에서 소스를 넣습니다 소스를 넣고요 75 그대로 해 가지고 값을 찍어 보겠습니다 자 러닝 501이 나오죠 자 오늘 어 포인트 관련돼서 간단히 설명드렸는데요 아까 처음에 말씀드린 대로이이 선언할 때이 주소를 가르치고자 하는 것이 포인트다 포인터다 포인터 포인터 그리고 선언할 때는 이런 식으로 선언한다 그리고이 값을 어피를 사용할 때는이 주소를 어 입력한다 그리고 어 변수 아 그 배 배열을 만약에 선언을 인트 뭐가 5다 이렇게 선언이 돼 있다고 하면은 어이 값은 이렇게 시작이 되지만 어 이렇게 해가지고 5까지 4까지 그죠 4까지 나오겠지만 이것의 주소는 이렇게 a0 또는 또는 a 그만 해도 이것은 주소다 그래서 a 피에 넣 수 있는 것이 되죠 또는 이걸 피해 넣어도 되고 자 다음 변수를 가르칠 때는 a + 1 이다 요렇게만 기억하셔도 어이 개념까지 딱 잡고 어 이런 비슷한 유형의 문제들을 대해 보시면은 어 좀 쉽게 접근을 하실 수 있을 것 같습니다 포인트 여기까지만 이해하셔도 어 좀 개념을 잡으시는데 도움이 될 것 같아서 이렇게 영상 남겨봤습니다 또 궁금하신 내용 있으면 질문 주시고요 감사합니다
# 네 안녕하세요 저는 올해로 7년 차 프로그램인 전문 강사이자 컨텐츠 개발 팀의 총괄을 맡고 있는 교육 PM 있니다 오늘은 강사 생활을 하면서 학생들이 질문을 가장 많이 하고 헷갈려했던 주제를 가지고 왔는데요네 첫 번째 C 언어와 씨뿔뿔 언어는 같은 언어인가요네 예전에 학원에 있을 때 제가 정말 뜨악했던 경험이 있는데 제가 가르치는 학생들 중에서 한 명이 저한테 와서 그러는 거예요 선생님 언어랑 별불 언어는 같은 언어죠 저희 학교 쌤이 그랬어요 와 이때 진짜 어떻게 말을 해야지네 물론 헷갈릴 수 있는 부분이고 많은 분들이 뭐 C 씨뿔뿔 뭐 둘 다 씨로 시작하니까 같은 언어라고 생각하시는 분들이 많 다치지만 저에게는 적자는 충격이었기 그 학생을 붙잡고 한시간 동안 설명을 했던 기억이납니다 여러분 씨랑 뿔은 다른 언어예제네 계속해서 알아볼게요네 시 언어의 경우 아주 오래전 1972년 와 제 나이보다 훨씬 많네요요 데니스 리치가 만든 언어인데 씨는 요새 많이 사용하는 자바나 파이썬 뭐 수많은 언어들이 아버지라고 할 정도로네 마주 많은 영향을 끼쳤어요 바로이 씨뿔뿔이 언어에서 파생되어 발전된 언어인 거죠네 사실 처음에 풀이 나타났을 때는음 시어의 부석 정도요 수준이었는데 시간이 흐르면서 시어를 넘어섰다는 평가를 받고 있습니다네 두 번째로 갈게요네 두 번째 시어와 불의 차이점은네는 절차 언어 불은 객체 언어입니다 요렇게 딱 한 줄로 정의를 하고 싶지만 이렇게 말하면 다들 이게 무슨 말이지 하실테니까네 하나하나 같이 볼게요 일단 절차 제형 언어부터 볼게요 절차라고 하면 함수네 프로시저 아고 할 수 있겠죠 말 그대로이 함수를 이용해서 프로그램을 만들어 순차적으로 실행이 되는 언어라고 할 수 있는데요음 코드 일자 순서대로만 움직이 때문에 메모리가 적은 곳에서도 잘 돌아가고네 속도가 굉장히 빨라요네 하지만 단점이 있어요네 그 정해진 순서대로만 움직이니 유지보수도 어렵고네 한 부분에서 문제가 발생하면이 전체적으로 문제를 해결해야 한다는 단점이 있었죠 그래서 이런 단점을 극복하기 위해 객체지향 언어가 나타나게 된 건데요 절차 언어와 개체 언어는 서로 반대 되는 개념이 아니에요네 절차지향 프로그래밍 기반 위에서 객체지향 프로그래밍이 탄생한 것이고 어찌 보면 절차 제 언어가 가지고 있는 그 부족함을 객체 제 언어가 보완해 주는 역할이라고 볼 수 있습니다이 두 가지를 가리는 가장 중요한 차이는네 절차지향 언어에는 함수가 있고네 계체 지에도 함수는 있어요네 함수는 있지만 그 함수 보다 더 큰 틀의 객체가 존재한다라는 것에서 큰 차별점이 차이점이 있습니다네 객체라는 말이 좀 생소하고 어려워하시는 분들이 많더라고요네 그래서 예시를 하나 들어보려고 하는데 제가 학부 때 어 교수님들이 항상 객체를 붕어방의 비유를 해 주셨거든요데 솔직히 그때는이가 정말 하나도 안 됐어요 근데 지금와서 생각해 보면 그 베이직한 붕어 방계 시가 아주 딱이더라고요 자 여러분 붕어빵을 만들기 위해서는 뭐가 필요하죠 붕어빵 모양의 틀이 있죠 그 틀 안에 파이나 슈크림 뭐 요새는 고구마도 넣더라고요이 각각의 재료를 넣어 붕어빵을 만들고 이렇게 만들어진 붕어빵을 우리는네 개체라고 하며 그 붕어빵을 만드는 틀을 클래스라고 합니다 네 붕어방 틀이라는이 클래스를 이용해서 그 안에 들어갈 재료들만 바꿔서 새로운 붕어방 즉 객체를 만드는 거죠네 객체 단위로 프로그램이 구성되기 때문에 오류가 발생했을 때 그 문제가 되는 클래스만 수정하면 되니까네 유지보수가 용이하겠죠 자 오늘이 시간에는 와 씨불 절차지향과 객체지향 언어의 차이점에 대해서 알아보는데 어떠 까요네 씨은 시 언어에서 파생된 서로 다른 언어라는 것 언어는 절차 제 언어로 함수로 짜여진 프로그램을 순서대로 실행하게 되지만네 불은 객체지향 언어로 독립적인 객체들이 서로 상호 작용하면서 진행되는 프로그래밍 언어라는 것이 사실들은 기억해 주시고요 오늘 강의는 여기까지 할게요 그럼 안녕 Ah
# 승리하세요 엎드릴 낙서 입니다 자 이번 시간에는 이지 드디어 클래스 라는 개념에 대해서는 배워 볼 건데 일단은 많은 사람이 금동 라는게 있어서 이것부터 타면 짚고 넘어가 볼게요 뭐냐면요 클래스가 클래스 엄호 아 뭔지 아무것도 모르셔도 일단 들어보세요 왜냐하면 제가 스 트 로 트 온 걸 배워 짜요 그리고 앞으로 이제 클래스라는 애를 배울 건 4 이스트 루트 란 클래스 의 차이점은 딱 한가지 밖에 없어요 정말 딱 한가지 밖에 없는데 그러면 클래스를 배열하면 지금까지 배웠던 스트로크 에다가 그 차이 점 하나만 더 배우면 클래스를 다 배우는 건가 라고 하실 수 있겠죠 근데 그런건 아니구요 뭐냐면 우리가 지금까지 배웠던 이제 cc 어머 에서 호소 체를 배운 거고 이게 싶을 블로잉 넘어오면서 빛의 지안 프로그래밍 이라는 새로운 패러다임을 추고 를 하게 되요 그래서 그 패러다임 외에도 많은 패러다임을 구현 하지만 기본적으로 스트럭 트에 여러가지 기능들이 추가가 됩니다 근데 이제 그 기능들이 대목을 객체지향 프로그래밍과 관련이 돼 있는 기능들이 달하는 것을 필자는 알고 시작을 했으면 좋겠어요 나 무슨 말이냐면 일단 c 언어의 스트록 트랑 싶을 프레스트 오픈 완전히 다른 거고 시험의 스트록 터에서 엄청나게 많은 기능들이 추가가 되는 게 싶을 브레스트 로 크고 여기서 딱 한 가지의 차이점을 갖고 있는게 바로 클래스 달하는 정보만 일단 말고 시작을 해 주셨으면 좋을 것 같아요 자 그러면 간단하게 클래스 에 대한 간단한 설명부터 한번 시작을 해볼게요 클래스 라는 건 어떤 뭐냐면요 저는 이렇게 얘기를 해요 플랫은 은 자료 저장 플러스 자료처리 링 라고 얘기합니다 자 지금 제가 쓰는 거에요 사실 클래스 의 가장 기본적인 기능이 되는거예요 나 클래스 는 이거 말고도 엄청나게 많은 기능들이 있는데 그 중에서 가장 기본이 되는 기능이라고 제가 생각을 하는게 이 두가지 입니다 그러니까 이게 뭐냐면요 자료를 저장하기 위해선 어떤 말을 쓰면 변수라는 벌써 적 어적 그 사람이 자료를 처리하기 위해서 저희가 쓰는 것은 함수 라는걸 써요 그래서 클래스 는 병수 란 함수를 묶어놓은 형태라고 볼 수 있어요 물론 이게 클래스의 전부는 아니죠 어쨌든 저희가 이제 변수를 함수를 묶어 없는 것은 사실 스트록 트에서 도 가능 있잖아요 그죠 저희가 에서 안에 구조체에 대해서 배우면서 싶을 벌에서 는 구조체 안에 함수도 넣을 수 있다 라고 간단하게 얘기를 한 적이 있었어요 내 기억에 안 나시면 한번 돌려보세요 그래서 아 그럼 일단 그렇구나 라는 걸 알았으면 뭐 조금 더 정확하게 줄로 한번 설명을 해볼게요 뭐냐면요 이 클래스라는 거든요 특정한 정보를 수행하기 위한 변수와 참수를 듯 놓아둔 술 자 여기 서서 1 트리 라는 개념이 되게 중요한데 이혼 이제 차차 알아가면 될 것 같고 어쨌든 이틀이 라는건 어떤 거군요 예를 들어서 인트라 는 트리 있다고 쳐 발 인 트 aec 이런식으로 만들 수 있잖아요 그럼 이제 인트라 는 어떤 특성을 가진 a 라는 변수가 만들고 삐 라는 변수도 만들고 씨라는 교수도 만들 수 있으니까 무슨 말이냐면 얘네들은 붕어빵 2대 비유를 많이 하는데 어 인턴 이제 붕어빵 틀이 되는거고 2 a b c 라는 병 소들은 붕어빵이 되는것처럼 이 클래스라는 이고요 붕어빵 크기라고 생각하시면 될 것 같아요 그러나 어떤 변수를 찍어내기 위한 트리 다 그런 사실 클래스 라는게 어떤 거랑 똑같네 하면요 사실 클래스라는 것 자체도 잘 형으로 볼 수 있어요 왜냐하면 트랙터 자료형 년 전에 거죠 그래서 이 클래스를 다른 말로 물론 이 시험은 싶을 폰에서는 주로 클래스 라고 부르지만 이거를 타입이라고 도플러 요 그럼 이 이틀을 갔다가 찍어낸 것을 뭐라고 부르냐 민요 그걸 바로 객체 라고 부릅니다 객체지향 프로그래밍 할때 그 바로 객체 요 그래서 우리가 뭐 이걸 굳이 영어로 하자면 모호 섹터가 되겠어 그래서 객체지향 프로그래밍을 영어라는 오브젝트 오리엔 티브 프로그래밍 이러한데 o 필요가 저주로 으 그렇다 1 상식으로 알고 계시면 좋을 것 같아요 그래서 이 개체 라는것은 클래스 라는 틀로 찍어낸 거예요 그 틀을 이용하여 찍어낸 개체 라고 보시면 될 것 같아요 그러나 결국에는 얘는 뭐 랑 비슷한 개념이라면 변수 맛 즉 메모리 상의 공간을 의미 를 하게 점에서 그래서 클래스 라는 객체를 초반 해 구별을 못하시는 분들을 위해서 제가 조금 자세하게 설명 했어요 자 그럼 여기까지 이제 대충 감을 잡으셨습니다 이제 예제를 본격적으로 한번 작성을 해 볼게요 그래서 못하게 니지 애플로 더러 일단 먼저 시켜 줄게요 4 자 이렇게 하신 다음에 어떤거를 해볼 건 요 텔레비전을 한번 만들어 볼까요 그래서 어떤 기능들이 녀 뭐 그냥 단순한 2 데모 전원 전원 키고 끄고 그 다음에 뭐 채널 볼륨 요정도만 기능을 갖고 있는 간단한 텔레비전을 이제 프로그램으로 한번 작성을 해 볼 건데 뭐 일단은 t'aime 슨 여러가지 속성이 있죠 자료를 저장을 해야 되는데 자료 소장이 이제 텔레비 너의 속성을 저장할 것 어떤 정보를 저장할 거야 뭐 사실 뻔하죠 그죠 어떤 정보 왜냐면 쿨 타워 본 낮 전원이 켜져 있는지 꺼져 있는지 를 저장하는 현수를 하나를 만들고 그 다음에 채널을 소장하는 편수를 떠날 분들께 채널 그 다음에 볼륨을 저장하는 변수를 또 하나 만들어 볼게요 자 이렇게 간단하게 어떤 구조체를 저희가 만들어 봤어요 그저 그 다음이 메인 함수 안으로 들어가볼게요 메인 어서 안 해 나가기 이제 뭐 전원을 한번 켜 볼게요 led tv 라는 만들어 볼까요 lg tv 하나만으로 올게요 그 다음에 a 점 파워 오는 투로 이렇게 하면 이제 뭐 db 가 켜졌다 고 생각을 해봅시다 나의 애니 점 뭐 채널을 일단 10번 으로 틀어 보고요 그 다음에 뭐 볼륨을 갖다가 도입 정도라면 써볼게요 자 이렇게 하면 이제 뭐 그냥 팀이 가 나오겠죠 그래서 테레비 에 그냥 단순한 모델을 한번 만들어 볼까요 뭐 이걸 실행을 지켜보는 의미 놓게 서버 더 그래서 뭐 여기서 문제점은 굳이 찾자면 어떤게 있냐 민요 예를 들어서 볼륨 2일부터 0부터 100까지 라고 쳐봐 요 그러면 일어서서 볼륨을 여우 프로그래머가 실수를 여기다가 막 20 같은걸 조 쓰면 큰일 나겠죠 0부터 100까지 인데 걸려온 120으로 지금 막 스피커 찢어질 수 있는 곳엔 하구요 그래서 이런 경우가 이제 발생하면 안 되잖아요 그럼 이제 프로그래머가 여기서 중 일을 해서 패 이하의 숫자를 입력을 해야 되겠지만 최대치 보다 높음 값을 가질 수 있는 가능성이 있는 것을 해보죠 그래서 그런 경우를 방지를 하기 위해서 저희가 쓸 수 있는 게 어떤 이념이 뇨 함수로 쓸 수 있어요 그래서 트로트 에다가 볼륨을 세팅을 하는 함수를 하나를 만들어 볼게요 그래서 보이 이드 3 톨 륨 이라고 하구요 그런데 움짤 어깨 오프셋 볼륨 이렇게 한 다음에 매개변수로 이제 거리라는 볼륨을 얼마로 할 건지를 이렇게 받아요 자 그럼 여기 잎을 하나를 만드셔서 여기다가 볼륨이 매개변수로 가든이 볼륨이 라는 애가 0 이상이고 그리고 예 2 i 이때만 해도 테이 i've 데만 볼륨을 바꾸도록 해주면 안전한 코드 가 되겠죠 개념 여기에 막 섬 같은게 들어와도 이건 조건의 충족을 안하기 때문에 이 품은 안으로 안들어 갈거 안되구요 그럼 볼륨이 한바뀌 있죠 그리고 골룸이 - 값이 나왔다고 해도 볼륨 아끼지 않을 거에요 이 폼을 안으로만 들어가니까 그럼 그래서 이렇게 하면은 금 안전한 코드를 만들 수 있어요 그럼 al g.na 점 3 볼륨 같은거 해주시고 여기다가 50 이렇게 해주시면 볼륨 이제 100을 넘고 아음속 안아 버리는 그런 가능성은 배제 를 할 수 있는 거죠 근데 이것도 완벽한 배 시간이 왜냐하면 이 3 볼륨 이라는 함수만 쓴 난 괜찮은데 예를 들어서 이색 볼륨 이라는 걸 까먹고 lg 점 볼륨을 아직도 쓴 프로그래머가 있다고 서가 요마 이런식으로 하면 이제 또 문제가 생기자 는 입 올림 이란 함수를 안 쓰고 싶다는 거죠 자 그래서 10불 뿔에서 새로 지원을 해주는 기능이 어떤 거냐면 요 접근제어 지시자 하는거예요 그래서 이게 뭐냐면 간단히 얘기하면 이런거요 제 보유함 소매 에서는 볼륨 접근할 수 있으니까 볼륨의 값을 바꿀 수도 ...
# 고딩 테스트 10주 만에 끝낸다 씨뿔뿔 10조 완성 코인 테스트 강사 큰돌입니다 저는요 백준상이 0.1% 전 네이버 개발자 4년차 알고리즘 강사로서 네이버 카카오 라인 삼성 코인 테스트 합격자를 배출한 경험이 있습니다 여러분 어떤 코딩 테스트 강의를 들어야 될까요 강의 커리큘럼 하나만으로 코딩 테스트를 합격시키는 강의를 들어야 하지 않을까요 저는요 알고리즘 1도 모르는 학생을 단 10주 만에 네이버 카카오 라인 삼성전자 등의 합격시킨 경험이 있습니다 10주 동안 여러분들은 씨뿔뿔의 기본 그리고 전반적인 알고리즘 개념 복잡도 제기함수 누적합 구현 그래프에서 dfs bfx 등을 배우고요 그리고 코딩 테스트의 자주 나오는 로직 그리고 160개 문제 + 추천 문제까지 이렇게 해서 총 233강을 여러분들은 10주 동안 배우게 되는 겁니다 10주 그리고 총 233강만으로 여러분들은 코딩 테스트를 마스터 할 수 있게 되는 겁니다 제 강의는요 상위 0.1% 그리고 마데틀 팁을 여러분들께 선사합니다 여러분들은 제 강의를 만약에 들으시면 다른 답안을 찾아다니면서이 코드가 좋을까 조코드가 좋을까 고민할 필요가 없습니다 왜 제 코드가 최고니까요 아래 보시면은 어떤 문제에 제가 제출한 코드가 6위인거를 볼 수가 있는데요 이만큼 정말 효율적인 정말 좋은 코드를 여러분들께 알려주려고 노력을 합니다 그래서 제 강의를 들으시면 다른 좋은 답안을 찾아다니면서 시간을 낭비할 필요가 없다라는 거죠 그리고 저는 1700문제 정도 좀 많이 풀어봤는데요이 짬밥으로부터 나오는 마제 뜰 팁을 여러분들께 알려드립니다 여러분 이런 경험해 보신 적 있으실 거예요 분명히 예제는 맞고 로직도 맞는데 제출하면 틀렸대 어 이거 맞는데 왜 틀리지라는 경험 해보신 적 있으실 겁니다 그런 경험들에 대해서 이렇게 하면 틀려요 이렇게 하면 맞아요 그러니까 이렇게 하는게 좋습니다라는 그런 마제트를 팁을 여러분들께 알려드립니다 그리고 160개의 달하는 문제를 풀이합니다 이거는 국내 단일 강좌 기준 1위로 정말 많은 문제를 여러분들께 알려드립니다 그리고 접근법부터 가르치는 풀이법을 제공합니다 예를 들어서 어떤 문제의 풀이법이 그리디라고 칠게요 그냥 여러분 어 이거 그리드로 푸는 거예요라고 알려줄 수도 있겠죠 근데 사실은 이렇게 알려 줘야 됩니다 뭐냐면 문제를 보고요 그 문제에 최대 범위 최소 범위를 파악해서 그 범위를 기반으로 어 이거 완탕 무식하게 풀 수 있지 않을까라고 첫 번째는 생각을 해야 되고요 그 다음에 어 이거 dp로 풀 수 있지 않을까라고 생각하면서 그리디 이런 식의 문제를 어떻게 푸는지에 대한 적근법부터 알려준다라는 거예요 왜 완탕으로 풀어야 되냐 왜 dp로 풀어야 되냐 왜 이거는 최소값부터 정해야 되고 왜 이거는 최대값부터 정해야 되냐 문제에 풀이 방법을 알려주는 것뿐만 아니라 그 풀이가 왜 그런 풀이로 나왔는지를 여러분들께 순차적으로 알려드립니다 저는요 사실 알고리즘을 그렇게 잘하지는 못했습니다 근데 정말 노력을 해 갖고 지금은 어느 정도 알고리즘을 잘한다라고 할 수가 있는데요 그래서 조금 더 여러분들의 입장에 서서 접근법을 알려줄 수 있다라고 자부합니다 왜 저도 이런 적이 있거든요 저도 알고리즘 정말 어려워했던 시절이 있기 때문에 그 입장에 서서 여러분들이 뭘 궁금해 하는지 뭘 어려워 하는지 알기 때문에 그 접근법부터 시작해서 여러분들께 알고리즘을 쉽고 그리고 정말 제대로 알려드릴 수가 있습니다 그리고 장점 한 가지 또 남았습니다 뭐냐면 사실 제 강의는요 2022년 인프런 강의 2425개 중에 업데이트 강의를 가장 많이 한 강의 1위로 선정되기도 했습니다 그만큼 여러분들이 어떤 피드백을 주신다면 여러분들이 제 강의를 듣고 어 선생님 이거 좀 이해가 안 돼요 어 선생님 이거 혹시 자세하게 조금 더 해주실 수 있을까요라고 하면은 피드백을 정말 많이 반영하는 편입니다 그러한 업데이트를 통해서 여러분들이 정말 10주 만에 코딩 테스트 합격할 수 있을 정도로 정말 노력을 많이 하고 있다라는 겁니다 네 노력하는 강의고요 제 강의를 들으시면서 정말 10주만 절 믿고 열심히 따라오기만 정말 문제 풀고 제 강의 듣고 해솔 코드 공부하시고 그러면은 정말 쉽지만은 코딩 테스트 합격할 수 있습니다

# %% [markdown]
# Wikipedia API를 이용하여 관련 키워드 추출

# %%
import requests
import json

# API 정보
WIKI_API_KEY = "dnslyvuqrbowvxharnwgohxaurtpwn"
url = 'http://www.wikifier.org/annotate-article'

params = {
    'text': full_transcript5,
    'lang': 'ko',
    'userKey': WIKI_API_KEY,
    'pageRankSqThreshold': 0.8,
    'applyPageRankSqThreshold': 'true',
    'nTopDfValuesToIgnore': 100,
    'nWordsToIgnoreFromList': 100
}

response = requests.post(url, data=params)
wikis = response.json()

wikis
# Out:
# {'annotations': [{'title': '십주',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%8b%ad%ec%a3%bc',
#    'lang': 'ko',
#    'pageRank': 0.01360310275286806,
#    'cosine': 0.005616274194495671,
#    'wikiDataItemId': 'Q12604968',
#    'wikiDataClasses': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': '',
#    'supportLen': 6,
#    'support': [{'wFrom': 2,
#      'wTo': 2,
#      'chFrom': 7,
#      'chTo': 9,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 55,
#      'wTo': 55,
#      'chFrom': 214,
#      'chTo': 216,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 65,
#      'wTo': 65,
#      'chFrom': 254,
#      'chTo': 256,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 100,
#      'wTo': 100,
#      'chFrom': 395,
#      'chTo': 397,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 105,
#      'wTo': 105,
#      'chFrom': 413,
#      'chTo': 415,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 487,
#      'wTo': 487,
#      'chFrom': 1908,
#      'chTo': 1910,
#      'pMentionGivenSurface': 0.1908396946564886,
#      'pageRank': 0.002483222470780273,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '전두환',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%a0%84%eb%91%90%ed%99%98',
#    'lang': 'ko',
#    'pageRank': 0.00627390245953679,
#    'cosine': 0.02413987717307017,
#    'secLang': 'en',
#    'secTitle': 'Chun Doo-hwan',
#    'secUrl': 'http://en.wikipedia.org/wiki/Chun_Doo-hwan',
#    'wikiDataItemId': 'Q14362',
#    'wikiDataClasses': [{'itemId': 'Q5', 'enLabel': 'human'},
#     {'itemId': 'Q110551885', 'enLabel': 'mammal'},
#     {'itemId': 'Q215627', 'enLabel': 'person'},
#     {'itemId': 'Q26401003', 'enLabel': 'individual animal'},
#     {'itemId': 'Q164509', 'enLabel': 'omnivore'},
#     {'itemId': 'Q154954', 'enLabel': 'natural person'},
#     {'itemId': 'Q12898224', 'enLabel': 'vertebrate'},
#     {'itemId': 'Q795052', 'enLabel': 'individual'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q110224119', 'enLabel': 'individual organism'},
#     {'itemId': 'Q729', 'enLabel': 'animal'},
#     {'itemId': 'Q72638', 'enLabel': 'consumer'},
#     {'itemId': 'Q106559804', 'enLabel': 'person or organization'},
#     {'itemId': 'Q7239', 'enLabel': 'organism'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q159344', 'enLabel': 'heterotroph'},
#     {'itemId': 'Q66394244', 'enLabel': 'physical anatomical entity'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q27043950', 'enLabel': 'anatomical entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q53617407', 'enLabel': 'material entity'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'}],
#    'dbPediaTypes': ['Person',
#     'Agent',
#     'President',
#     'Politician',
#     'OfficeHolder'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Chun_Doo-hwan',
#    'supportLen': 1,
#    'support': [{'wFrom': 16,
#      'wTo': 16,
#      'chFrom': 59,
#      'chTo': 59,
#      'pMentionGivenSurface': 0.002777157876466067,
#      'pageRank': 3.613661642122359e-05,
#      'prbConfidence': 0.2051506686574966,
#      'entropy': 2.572398693965841}]},
#   {'title': '네이버',
#    'url': 'http://ko.wikipedia.org/wiki/%eb%84%a4%ec%9d%b4%eb%b2%84',
#    'lang': 'ko',
#    'pageRank': 0.01004157553521444,
#    'cosine': 0.04222103248327937,
#    'secLang': 'en',
#    'secTitle': 'Naver',
#    'secUrl': 'http://en.wikipedia.org/wiki/Naver',
#    'wikiDataItemId': 'Q485639',
#    'wikiDataClasses': [{'itemId': 'Q186165', 'enLabel': 'web portal'},
#     {'itemId': 'Q35127', 'enLabel': 'website'},
#     {'itemId': 'Q1668024', 'enLabel': 'service on Internet'},
#     {'itemId': 'Q1076968', 'enLabel': 'digital media'},
#     {'itemId': 'Q1714118', 'enLabel': 'online publication'},
#     {'itemId': 'Q19967801', 'enLabel': 'online service'},
#     {'itemId': 'Q107307154', 'enLabel': 'virtual place'},
#     {'itemId': 'Q108637623', 'enLabel': 'integrating resource'},
#     {'itemId': 'Q119648796', 'enLabel': 'digital-native publication'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q1273271', 'enLabel': 'e-service'},
#     {'itemId': 'Q1640628', 'enLabel': 'network service'},
#     {'itemId': 'Q340169', 'enLabel': 'media'},
#     {'itemId': 'Q1209283', 'enLabel': 'electronic media'},
#     {'itemId': 'Q732577', 'enLabel': 'publication'},
#     {'itemId': 'Q11492760', 'enLabel': 'information services'},
#     {'itemId': 'Q115095765', 'enLabel': 'location'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q12774177', 'enLabel': 'means'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q7406919', 'enLabel': 'service'},
#     {'itemId': 'Q146923', 'enLabel': 'middleware of distributed system'},
#     {'itemId': 'Q104450446', 'enLabel': 'data carrier'},
#     {'itemId': 'Q115668308', 'enLabel': 'release'},
#     {'itemId': 'Q49848', 'enLabel': 'document'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q2143054', 'enLabel': 'material culture'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q8187769', 'enLabel': 'economic activity'},
#     {'itemId': 'Q146768', 'enLabel': 'middleware'},
#     {'itemId': 'Q17538423', 'enLabel': 'manifestation'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q37866906', 'enLabel': 'information resource'},
#     {'itemId': 'Q286583', 'enLabel': 'manifestation'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q11042', 'enLabel': 'culture'},
#     {'itemId': 'Q23498', 'enLabel': 'archaeology'},
#     {'itemId': 'Q23404', 'enLabel': 'anthropology'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q451967', 'enLabel': 'intentional human activity'},
#     {'itemId': 'Q125506646', 'enLabel': 'transfer'},
#     {'itemId': 'Q676202', 'enLabel': 'system software'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q3523102', 'enLabel': 'source of information'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q2515887', 'enLabel': 'pattern of behavior'},
#     {'itemId': 'Q1066186', 'enLabel': 'study of history'},
#     {'itemId': 'Q34749', 'enLabel': 'social science'},
#     {'itemId': 'Q61788060', 'enLabel': 'human activity'},
#     {'itemId': 'Q1150070', 'enLabel': 'change'},
#     {'itemId': 'Q52948', 'enLabel': 'interaction'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q31464082', 'enLabel': 'source'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q80083', 'enLabel': 'humanities'},
#     {'itemId': 'Q33122512', 'enLabel': 'social sciences and humanities'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q111931734', 'enLabel': 'effect'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q336', 'enLabel': 'science'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2006324', 'enLabel': 'agreement'},
#     {'itemId': 'Q1151067', 'enLabel': 'rule'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q20937557', 'enLabel': 'sequence'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q202722', 'enLabel': 'consensus'},
#     {'itemId': 'Q628523', 'enLabel': 'message'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': ['Agent', 'Work', 'Organisation', 'Company', 'Website'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Naver',
#    'supportLen': 3,
#    'support': [{'wFrom': 17,
#      'wTo': 17,
#      'chFrom': 61,
#      'chTo': 63,
#      'pMentionGivenSurface': 0.07680332122470161,
#      'pageRank': 0.0009993714014216487,
#      'prbConfidence': 0.7169239950475784,
#      'entropy': 0.3051997120334802},
#     {'wFrom': 22,
#      'wTo': 22,
#      'chFrom': 83,
#      'chTo': 85,
#      'pMentionGivenSurface': 0.07680332122470161,
#      'pageRank': 0.0009993714014216487,
#      'prbConfidence': 0.7169239950475784,
#      'entropy': 0.3051997120334802},
#     {'wFrom': 57,
#      'wTo': 57,
#      'chFrom': 221,
#      'chTo': 223,
#      'pMentionGivenSurface': 0.07680332122470161,
#      'pageRank': 0.0009993714014216487,
#      'prbConfidence': 0.7169239950475784,
#      'entropy': 0.3051997120334802}]},
#   {'title': '알고리즘',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%95%8c%ea%b3%a0%eb%a6%ac%ec%a6%98',
#    'lang': 'ko',
#    'pageRank': 0.01673472913418921,
#    'cosine': 0.07092696236311584,
#    'secLang': 'en',
#    'secTitle': 'Algorithm',
#    'secUrl': 'http://en.wikipedia.org/wiki/Algorithm',
#    'wikiDataItemId': 'Q8366',
#    'wikiDataClasses': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Algorithm',
#    'supportLen': 7,
#    'support': [{'wFrom': 20,
#      'wTo': 20,
#      'chFrom': 73,
#      'chTo': 76,
#      'pMentionGivenSurface': 0.07938257993384785,
#      'pageRank': 0.001032932936908469,
#      'prbConfidence': 0.8747030689512307,
#      'entropy': 0.2979445744932716},
#     {'wFrom': 50,
#      'wTo': 50,
#      'chFrom': 196,
#      'chTo': 199,
#      'pMentionGivenSurface': 0.07938257993384785,
#      'pageRank': 0.001032932936908469,
#      'prbConfidence': 0.8747030689512307,
#      'entropy': 0.2979445744932716},
#     {'wFrom': 72,
#      'wTo': 72,
#      'chFrom': 284,
#      'chTo': 287,
#      'pMentionGivenSurface': 0.07938257993384785,
#      'pageRank': 0.001032932936908469,
#      'prbConfidence': 0.8747030689512307,
#      'entropy': 0.2979445744932716},
#     {'wFrom': 362,
#      'wTo': 362,
#      'chFrom': 1426,
#      'chTo': 1430,
#      'pMentionGivenSurface': 0.132034632034632,
#      'pageRank': 0.00171804595359352,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 374,
#      'wTo': 374,
#      'chFrom': 1472,
#      'chTo': 1476,
#      'pMentionGivenSurface': 0.132034632034632,
#      'pageRank': 0.00171804595359352,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 396,
#      'wTo': 396,
#      'chFrom': 1557,
#      'chTo': 1560,
#      'pMentionGivenSurface': 0.07938257993384785,
#      'pageRank': 0.001032932936908469,
#      'prbConfidence': 0.8747030689512307,
#      'entropy': 0.2979445744932716},
#     {'wFrom': 418,
#      'wTo': 418,
#      'chFrom': 1643,
#      'chTo': 1647,
#      'pMentionGivenSurface': 0.132034632034632,
#      'pageRank': 0.00171804595359352,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '카카오 (기업)',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%b9%b4%ec%b9%b4%ec%98%a4_(%ea%b8%b0%ec%97%85)',
#    'lang': 'ko',
#    'pageRank': 0.008906267904709561,
#    'cosine': 0.02239735598820087,
#    'secLang': 'en',
#    'secTitle': 'Kakao',
#    'secUrl': 'http://en.wikipedia.org/wiki/Kakao',
#    'wikiDataItemId': 'Q17684312',
#    'wikiDataClasses': [{'itemId': 'Q4830453', 'enLabel': 'business'},
#     {'itemId': 'Q6881511', 'enLabel': 'enterprise'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q12569864', 'enLabel': 'economic entity'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q167037', 'enLabel': 'corporation'},
#     {'itemId': 'Q106559804', 'enLabel': 'person or organization'},
#     {'itemId': 'Q106668099', 'enLabel': 'corporate body'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q854457', 'enLabel': 'complex system'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q783794', 'enLabel': 'company'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q131085629', 'enLabel': 'collective agent'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q21980538', 'enLabel': 'commercial organization'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'}],
#    'dbPediaTypes': [],
#    'dbPediaIri': '',
#    'supportLen': 2,
#    'support': [{'wFrom': 23,
#      'wTo': 23,
#      'chFrom': 87,
#      'chTo': 89,
#      'pMentionGivenSurface': 0.3424242424242424,
#      'pageRank': 0.004455653604237621,
#      'prbConfidence': 0.518050789691686,
#      'entropy': 1.18073560468925},
#     {'wFrom': 58,
#      'wTo': 58,
#      'chFrom': 225,
#      'chTo': 227,
#      'pMentionGivenSurface': 0.3424242424242424,
#      'pageRank': 0.004455653604237621,
#      'prbConfidence': 0.518050789691686,
#      'entropy': 1.18073560468925}]},
#   {'title': '삼성전자',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%82%bc%ec%84%b1%ec%a0%84%ec%9e%90',
#    'lang': 'ko',
#    'pageRank': 0.01523993930088786,
#    'cosine': 0.02952000671416722,
#    'secLang': 'en',
#    'secTitle': 'Samsung Electronics',
#    'secUrl': 'http://en.wikipedia.org/wiki/Samsung_Electronics',
#    'wikiDataItemId': 'Q20718',
#    'wikiDataClasses': [{'itemId': 'Q4830453', 'enLabel': 'business'},
#     {'itemId': 'Q6881511', 'enLabel': 'enterprise'},
#     {'itemId': 'Q891723', 'enLabel': 'public company'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q12569864', 'enLabel': 'economic entity'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q167037', 'enLabel': 'corporation'},
#     {'itemId': 'Q134161', 'enLabel': 'joint-stock company'},
#     {'itemId': 'Q106559804', 'enLabel': 'person or organization'},
#     {'itemId': 'Q106668099', 'enLabel': 'corporate body'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q854457', 'enLabel': 'complex system'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q783794', 'enLabel': 'company'},
#     {'itemId': 'Q33685', 'enLabel': 'limited company'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q131085629', 'enLabel': 'collective agent'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q21980538', 'enLabel': 'commercial organization'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q567521', 'enLabel': 'commercial company'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q5621421', 'enLabel': 'private company'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'}],
#    'dbPediaTypes': ['Agent', 'Organisation', 'Company'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Samsung_Electronics',
#    'supportLen': 2,
#    'support': [{'wFrom': 25,
#      'wTo': 25,
#      'chFrom': 94,
#      'chTo': 95,
#      'pMentionGivenSurface': 0.206555756876956,
#      'pageRank': 0.002687721219996432,
#      'prbConfidence': 0.297532196052867,
#      'entropy': 1.70016198816651},
#     {'wFrom': 60,
#      'wTo': 60,
#      'chFrom': 232,
#      'chTo': 235,
#      'pMentionGivenSurface': 0.6704789135096497,
#      'pageRank': 0.008724329114068285,
#      'prbConfidence': 0.8770001098494155,
#      'entropy': 0.03967880376173608}]},
#   {'title': '구글',
#    'url': 'http://ko.wikipedia.org/wiki/%ea%b5%ac%ea%b8%80',
#    'lang': 'ko',
#    'pageRank': 0.007405576266443104,
#    'cosine': 0.01959006179114767,
#    'secLang': 'en',
#    'secTitle': 'Google',
#    'secUrl': 'http://en.wikipedia.org/wiki/Google',
#    'wikiDataItemId': 'Q95',
#    'wikiDataClasses': [{'itemId': 'Q4830453', 'enLabel': 'business'},
#     {'itemId': 'Q18388277', 'enLabel': 'technology company'},
#     {'itemId': 'Q5988403', 'enLabel': 'identity provider'},
#     {'itemId': 'Q891723', 'enLabel': 'public company'},
#     {'itemId': 'Q19967801', 'enLabel': 'online service'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q12569864', 'enLabel': 'economic entity'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q167037', 'enLabel': 'corporation'},
#     {'itemId': 'Q6881511', 'enLabel': 'enterprise'},
#     {'itemId': 'Q784561', 'enLabel': 'authentication server'},
#     {'itemId': 'Q134161', 'enLabel': 'joint-stock company'},
#     {'itemId': 'Q1668024', 'enLabel': 'service on Internet'},
#     {'itemId': 'Q11492760', 'enLabel': 'information services'},
#     {'itemId': 'Q106559804', 'enLabel': 'person or organization'},
#     {'itemId': 'Q106668099', 'enLabel': 'corporate body'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q854457', 'enLabel': 'complex system'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q783794', 'enLabel': 'company'},
#     {'itemId': 'Q1371279', 'enLabel': 'server software'},
#     {'itemId': 'Q33685', 'enLabel': 'limited company'},
#     {'itemId': 'Q1273271', 'enLabel': 'e-service'},
#     {'itemId': 'Q1640628', 'enLabel': 'network service'},
#     {'itemId': 'Q340169', 'enLabel': 'media'},
#     {'itemId': 'Q7406919', 'enLabel': 'service'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q131085629', 'enLabel': 'collective agent'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q21980538', 'enLabel': 'commercial organization'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q44127', 'enLabel': 'server'},
#     {'itemId': 'Q567521', 'enLabel': 'commercial company'},
#     {'itemId': 'Q146923', 'enLabel': 'middleware of distributed system'},
#     {'itemId': 'Q12774177', 'enLabel': 'means'},
#     {'itemId': 'Q104450446', 'enLabel': 'data carrier'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q8187769', 'enLabel': 'economic activity'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q994895', 'enLabel': 'technical system'},
#     {'itemId': 'Q4925872', 'enLabel': 'data processing system'},
#     {'itemId': 'Q5621421', 'enLabel': 'private company'},
#     {'itemId': 'Q146768', 'enLabel': 'middleware'},
#     {'itemId': 'Q17538423', 'enLabel': 'manifestation'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q451967', 'enLabel': 'intentional human activity'},
#     {'itemId': 'Q125506646', 'enLabel': 'transfer'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q2143054', 'enLabel': 'material culture'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q121182', 'enLabel': 'information system'},
#     {'itemId': 'Q676202', 'enLabel': 'system software'},
#     {'itemId': 'Q61788060', 'enLabel': 'human activity'},
#     {'itemId': 'Q1150070', 'enLabel': 'change'},
#     {'itemId': 'Q52948', 'enLabel': 'interaction'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q11042', 'enLabel': 'culture'},
#     {'itemId': 'Q23498', 'enLabel': 'archaeology'},
#     {'itemId': 'Q23404', 'enLabel': 'anthropology'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q111931734', 'enLabel': 'effect'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q2515887', 'enLabel': 'pattern of behavior'},
#     {'itemId': 'Q1066186', 'enLabel': 'study of history'},
#     {'itemId': 'Q34749', 'enLabel': 'social science'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q80083', 'enLabel': 'humanities'},
#     {'itemId': 'Q33122512', 'enLabel': 'social sciences and humanities'},
#     {'itemId': 'Q20937557', 'enLabel': 'sequence'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q336', 'enLabel': 'science'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q31464082', 'enLabel': 'source'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2006324', 'enLabel': 'agreement'},
#     {'itemId': 'Q1151067', 'enLabel': 'rule'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q202722', 'enLabel': 'consensus'},
#     {'itemId': 'Q628523', 'enLabel': 'message'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': ['Agent', 'Place', 'Organisation', 'Company'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Google',
#    'supportLen': 4,
#    'support': [{'wFrom': 31,
#      'wTo': 31,
#      'chFrom': 117,
#      'chTo': 120,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 6.483351144438778e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 64,
#      'wTo': 64,
#      'chFrom': 249,
#      'chTo': 252,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 6.483351144438778e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 425,
#      'wTo': 425,
#      'chFrom': 1671,
#      'chTo': 1674,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 6.483351144438778e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 529,
#      'wTo': 529,
#      'chFrom': 2059,
#      'chTo': 2062,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 6.483351144438778e-06,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '컴퓨터 프로그래밍',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%bb%b4%ed%93%a8%ed%84%b0_%ed%94%84%eb%a1%9c%ea%b7%b8%eb%9e%98%eb%b0%8d',
#    'lang': 'ko',
#    'pageRank': 0.009144195322282325,
#    'cosine': 0.06486473379798732,
#    'secLang': 'en',
#    'secTitle': 'Computer programming',
#    'secUrl': 'http://en.wikipedia.org/wiki/Computer_programming',
#    'wikiDataItemId': 'Q80006',
#    'wikiDataClasses': [{'itemId': 'Q11862829',
#      'enLabel': 'academic discipline'},
#     {'itemId': 'Q4671286', 'enLabel': 'academic major'},
#     {'itemId': 'Q66747126', 'enLabel': 'computer science term'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q12812139', 'enLabel': 'technical term'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Computer_programming',
#    'supportLen': 6,
#    'support': [{'wFrom': 34,
#      'wTo': 34,
#      'chFrom': 129,
#      'chTo': 130,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 42,
#      'wTo': 42,
#      'chFrom': 162,
#      'chTo': 163,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 84,
#      'wTo': 84,
#      'chFrom': 334,
#      'chTo': 335,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 110,
#      'wTo': 110,
#      'chFrom': 437,
#      'chTo': 438,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 489,
#      'wTo': 489,
#      'chFrom': 1915,
#      'chTo': 1916,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 525,
#      'wTo': 525,
#      'chFrom': 2046,
#      'chTo': 2047,
#      'pMentionGivenSurface': 0.0449438202247191,
#      'pageRank': 0.0005848128425567922,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '학생',
#    'url': 'http://ko.wikipedia.org/wiki/%ed%95%99%ec%83%9d',
#    'lang': 'ko',
#    'pageRank': 0.005475898151171174,
#    'cosine': 0.00869131145914424,
#    'secLang': 'en',
#    'secTitle': 'Student',
#    'secUrl': 'http://en.wikipedia.org/wiki/Student',
#    'wikiDataItemId': 'Q48282',
#    'wikiDataClasses': [{'itemId': 'Q12737077', 'enLabel': 'occupation'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q874405', 'enLabel': 'human social group'},
#     {'itemId': 'Q1807498', 'enLabel': 'social position'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q214339', 'enLabel': 'role'},
#     {'itemId': 'Q4164871', 'enLabel': 'position'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q4897819', 'enLabel': 'role'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q123241435', 'enLabel': 'realizable entity'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q123240632', 'enLabel': 'specifically dependent continuant'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'}],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Student',
#    'supportLen': 1,
#    'support': [{'wFrom': 53,
#      'wTo': 53,
#      'chFrom': 208,
#      'chTo': 210,
#      'pMentionGivenSurface': 0.009186351706036745,
#      'pageRank': 0.0001195335961000268,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '위안부',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%9c%84%ec%95%88%eb%b6%80',
#    'lang': 'ko',
#    'pageRank': 0.005912821040251694,
#    'cosine': 0.020551932937532,
#    'secLang': 'en',
#    'secTitle': 'Comfort women',
#    'secUrl': 'http://en.wikipedia.org/wiki/Comfort_women',
#    'wikiDataItemId': 'Q713540',
#    'wikiDataClasses': [{'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q83464', 'enLabel': 'euphemism'},
#     {'itemId': 'Q135010', 'enLabel': 'war crime'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q83267', 'enLabel': 'crime'},
#     {'itemId': 'Q1456832', 'enLabel': 'violation of law'},
#     {'itemId': 'Q123177272',
#      'enLabel': 'violation of international humanitarian law'},
#     {'itemId': 'Q4817637', 'enLabel': 'atrocity'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3537603', 'enLabel': 'transgression'},
#     {'itemId': 'Q896677', 'enLabel': 'wrongdoing'},
#     {'itemId': 'Q451967', 'enLabel': 'intentional human activity'},
#     {'itemId': 'Q123458532',
#      'enLabel': 'violation of international public law'},
#     {'itemId': 'Q11869657', 'enLabel': 'international crime'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q567555', 'enLabel': 'anomaly'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q61788060', 'enLabel': 'human activity'},
#     {'itemId': 'Q123458523', 'enLabel': 'violation of international law'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q20937557', 'enLabel': 'sequence'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'}],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Comfort_women',
#    'supportLen': 10,
#    'support': [{'wFrom': 70,
#      'wTo': 70,
#      'chFrom': 275,
#      'chTo': 277,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 83,
#      'wTo': 83,
#      'chFrom': 330,
#      'chTo': 332,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 89,
#      'wTo': 89,
#      'chFrom': 352,
#      'chTo': 354,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 106,
#      'wTo': 106,
#      'chFrom': 417,
#      'chTo': 419,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 123,
#      'wTo': 123,
#      'chFrom': 478,
#      'chTo': 480,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 181,
#      'wTo': 181,
#      'chFrom': 717,
#      'chTo': 719,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 237,
#      'wTo': 237,
#      'chFrom': 943,
#      'chTo': 945,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 253,
#      'wTo': 253,
#      'chFrom': 1010,
#      'chTo': 1012,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 420,
#      'wTo': 420,
#      'chFrom': 1652,
#      'chTo': 1654,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 426,
#      'wTo': 426,
#      'chFrom': 1676,
#      'chTo': 1678,
#      'pMentionGivenSurface': 2.566076469078778e-05,
#      'pageRank': 3.339000704872627e-07,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '황해도',
#    'url': 'http://ko.wikipedia.org/wiki/%ed%99%a9%ed%95%b4%eb%8f%84',
#    'lang': 'ko',
#    'pageRank': 0.005528985792259266,
#    'cosine': 0.00871358298440248,
#    'secLang': 'en',
#    'secTitle': 'Hwanghae Province',
#    'secUrl': 'http://en.wikipedia.org/wiki/Hwanghae_Province',
#    'wikiDataItemId': 'Q698214',
#    'wikiDataClasses': [{'itemId': 'Q699797',
# ...
#      'prbConfidence': 0.341996777926123,
#      'linPr': 0.8652482269503546,
#      'linkProb': 0.2,
#      'logLinkProb': 0.6185149837908823,
#      'score2': 0.004291722560249399,
#      'isBestCand': True},
#     {'title': '문자 인코딩',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%ac%b8%ec%9e%90_%ec%9d%b8%ec%bd%94%eb%94%a9',
#      'cosine': 0.008394188485483274,
#      'linkCount': 2,
#      'pageRank': 0.002820197087433216,
#      'prbConfidence': 0.2247345450407558,
#      'linPr': 0.7659574468085106,
#      'linkProb': 0.08,
#      'logLinkProb': 0.40132662131928},
#     {'title': '화음',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%99%94%ec%9d%8c',
#      'cosine': 0.02151206812120593,
#      'linkCount': 2,
#      'pageRank': 0.0009994752070689545,
#      'prbConfidence': 0.07964571233019394,
#      'linPr': 0.4018912529550828,
#      'linkProb': 0.08,
#      'logLinkProb': 0.40132662131928},
#     {'title': '목적 파일',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%aa%a9%ec%a0%81_%ed%8c%8c%ec%9d%bc',
#      'cosine': 0.004654503140617168,
#      'linkCount': 1,
#      'pageRank': 0.001330843936462728,
#      'prbConfidence': 0.1060516684858403,
#      'linPr': 0.4964539007092199,
#      'linkProb': 0.04,
#      'logLinkProb': 0.2370299675817646}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 523,
#    'wTo': 523,
#    'pageRank': 1.362522067737029e-05,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.001047120418848168,
#    'nodeId': 252988,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['정말'],
#    'candidates': [{'title': '정말',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%a0%95%eb%a7%90',
#      'cosine': 0.02618786861499974,
#      'linkCount': 2,
#      'pageRank': 0.0001492780281152432,
#      'prbConfidence': 1,
#      'linPr': 0.0591016548463357,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.0001492780281152432,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 0},
#   {'wFrom': 525,
#    'wTo': 525,
#    'pageRank': 0.0005848128425567922,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.0449438202247191,
#    'nodeId': 151678,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['코딩'],
#    'candidates': [{'title': '컴퓨터 프로그래밍',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%bb%b4%ed%93%a8%ed%84%b0_%ed%94%84%eb%a1%9c%ea%b7%b8%eb%9e%98%eb%b0%8d',
#      'cosine': 0.06486473379798732,
#      'linkCount': 8,
#      'pageRank': 0.009144195322282325,
#      'prbConfidence': 1,
#      'linPr': 0.9810874704491725,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.009144195322282325,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 0},
#   {'wFrom': 526,
#    'wTo': 526,
#    'pageRank': 0.000193450414077374,
#    'prbConfidence': 0.4107306735600356,
#    'pMentionGivenSurface': 0.01486697965571205,
#    'nodeId': 236908,
#    'mentionEntropy': 1.811278124459133,
#    'minDf': -1,
#    'wordsUsed': ['테스트'],
#    'candidates': [{'title': '테스트',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%85%8c%ec%8a%a4%ed%8a%b8',
#      'cosine': -99,
#      'linkCount': 7,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q224615'},
#     {'title': '소프트웨어 테스트',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%86%8c%ed%94%84%ed%8a%b8%ec%9b%a8%ec%96%b4_%ed%85%8c%ec%8a%a4%ed%8a%b8',
#      'cosine': 0.02560637097160271,
#      'linkCount': 3,
#      'pageRank': 0.002045342280238043,
#      'prbConfidence': 0.3075801794266316,
#      'linPr': 0.6524822695035462,
#      'linkProb': 0.375,
#      'logLinkProb': 0.6814911925632193},
#     {'title': '앤드루 마틴',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%95%a4%eb%93%9c%eb%a3%a8_%eb%a7%88%ed%8b%b4',
#      'cosine': 0.02189904751004949,
#      'linkCount': 3,
#      'pageRank': 0.001114963105100764,
#      'prbConfidence': 0.1676690279345592,
#      'linPr': 0.442080378250591,
#      'linkProb': 0.375,
#      'logLinkProb': 0.6814911925632193},
#     {'title': '시험',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%8b%9c%ed%97%98',
#      'cosine': 0.009156378414850319,
#      'linkCount': 1,
#      'pageRank': 0.002731270961571759,
#      'prbConfidence': 0.4107306735600356,
#      'linPr': 0.7588652482269503,
#      'linkProb': 0.125,
#      'logLinkProb': 0.3247342047137871,
#      'score2': 0.002731270961571759,
#      'isBestCand': True},
#     {'title': '테스트 크리켓',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%85%8c%ec%8a%a4%ed%8a%b8_%ed%81%ac%eb%a6%ac%ec%bc%93',
#      'cosine': 0.05312688607539874,
#      'linkCount': 1,
#      'pageRank': 0.0007582093579122208,
#      'prbConfidence': 0.1140201190787736,
#      'linPr': 0.3096926713947991,
#      'linkProb': 0.125,
#      'logLinkProb': 0.3247342047137871}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 528,
#    'wTo': 528,
#    'pageRank': 8.601509445533783e-05,
#    'prbConfidence': 0.2523363138337975,
#    'pMentionGivenSurface': 0.006610400217805608,
#    'nodeId': 7428,
#    'mentionEntropy': 2.594350538784976,
#    'minDf': -1,
#    'wordsUsed': ['수'],
#    'candidates': [{'title': '수요일',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ec%9a%94%ec%9d%bc',
#      'cosine': 0.01192263986344019,
#      'linkCount': 192,
#      'pageRank': 0.003795170544317591,
#      'prbConfidence': 0.0717203602511001,
#      'linPr': 0.8321513002364066,
#      'linkProb': 0.3542435424354243,
#      'logLinkProb': 0.8577473899913901},
#     {'title': '수나라',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%eb%82%98%eb%9d%bc',
#      'cosine': 0.02007169456836431,
#      'linkCount': 161,
#      'pageRank': 0.006060411177703387,
#      'prbConfidence': 0.1145284165386133,
#      'linPr': 0.933806146572104,
#      'linkProb': 0.2970479704797048,
#      'logLinkProb': 0.833609681097901},
#     {'title': '수 (불교)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98_(%eb%b6%88%ea%b5%90)',
#      'cosine': 0.004822533771271274,
#      'linkCount': 74,
#      'pageRank': 0.002916538407696807,
#      'prbConfidence': 0.05511614902244046,
#      'linPr': 0.7730496453900709,
#      'linkProb': 0.1365313653136531,
#      'logLinkProb': 0.7270557498736121},
#     {'title': '수 (수학)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98_(%ec%88%98%ed%95%99)',
#      'cosine': 0.02489851524777546,
#      'linkCount': 40,
#      'pageRank': 0.002947994475469087,
#      'prbConfidence': 0.05571059938675647,
#      'linPr': 0.7777777777777778,
#      'linkProb': 0.07380073800738007,
#      'logLinkProb': 0.642729059254129},
#     {'title': '수',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98',
#      'cosine': -99,
#      'linkCount': 26,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q12603095'},
#     {'title': '수 (문법)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98_(%eb%ac%b8%eb%b2%95)',
#      'cosine': 0.0122959845032797,
#      'linkCount': 19,
#      'pageRank': 0.001599729885378743,
#      'prbConfidence': 0.03023136966943462,
#      'linPr': 0.5602836879432624,
#      'linkProb': 0.03505535055350553,
#      'logLinkProb': 0.540684736977109},
#     {'title': '수 (심불상응행법)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98_(%ec%8b%ac%eb%b6%88%ec%83%81%ec%9d%91%ed%96%89%eb%b2%95)',
#      'cosine': 0.0104953515238501,
#      'linkCount': 13,
#      'pageRank': 0.001218357878287004,
#      'prbConfidence': 0.02302427912662404,
#      'linPr': 0.475177304964539,
#      'linkProb': 0.02398523985239853,
#      'logLinkProb': 0.488666123587273},
#     {'title': '태수',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%83%9c%ec%88%98',
#      'cosine': 0.00116508613184561,
#      'linkCount': 10,
#      'pageRank': 0.003127064312412626,
#      'prbConfidence': 0.05909462470675843,
#      'linPr': 0.7966903073286052,
#      'linkProb': 0.01845018450184502,
#      'logLinkProb': 0.452702491224078},
#     {'title': '수온',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ec%98%a8',
#      'cosine': -99,
#      'linkCount': 8,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q24855774'},
#     {'title': '십이연기설',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%8b%ad%ec%9d%b4%ec%97%b0%ea%b8%b0%ec%84%a4',
#      'cosine': 0.004947754817813489,
#      'linkCount': 6,
#      'pageRank': 0.002130509984756267,
#      'prbConfidence': 0.04026194392082592,
#      'linPr': 0.6643026004728132,
#      'linkProb': 0.01107011070110701,
#      'logLinkProb': 0.3826809699162621},
#     {'title': '수컷',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ec%bb%b7',
#      'cosine': 0,
#      'linkCount': 5,
#      'pageRank': 0.001594735908592155,
#      'prbConfidence': 0.03013699451289363,
#      'linPr': 0.5555555555555556,
#      'linkProb': 0.00922509225092251,
#      'logLinkProb': 0.3576892072090523},
#     {'title': '수 (수형도위)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98_(%ec%88%98%ed%98%95%eb%8f%84%ec%9c%84)',
#      'cosine': 0.00606265010152812,
#      'linkCount': 3,
#      'pageRank': 0.001042116896901706,
#      'prbConfidence': 0.01969371294300769,
#      'linPr': 0.4137115839243499,
#      'linkProb': 0.005535055350553505,
#      'logLinkProb': 0.2876676859012365},
#     {'title': '자수 (공예)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%9e%90%ec%88%98_(%ea%b3%b5%ec%98%88)',
#      'cosine': 0.01388351800225547,
#      'linkCount': 3,
#      'pageRank': 0.001534690431952582,
#      'prbConfidence': 0.02900226732059731,
#      'linPr': 0.5366430260047281,
#      'linkProb': 0.005535055350553505,
#      'logLinkProb': 0.2876676859012365},
#     {'title': '물',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%ac%bc',
#      'cosine': 0.01925608032977504,
#      'linkCount': 3,
#      'pageRank': 0.01335268453993883,
#      'prbConfidence': 0.2523363138337975,
#      'linPr': 0.9905437352245863,
#      'linkProb': 0.005535055350553505,
#      'logLinkProb': 0.2876676859012365,
#      'score2': 0.01335268453993883,
#      'isBestCand': True},
#     {'title': '공자 수',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b3%b5%ec%9e%90_%ec%88%98',
#      'cosine': 0.005436166642724798,
#      'linkCount': 2,
#      'pageRank': 0.0001646293356132872,
#      'prbConfidence': 0.003111131665943957,
#      'linPr': 0.06382978723404255,
#      'linkProb': 0.003690036900369004,
#      'logLinkProb': 0.2320884776820777},
#     {'title': '수족',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ec%a1%b1',
#      'cosine': 0.00900018356637278,
#      'linkCount': 2,
#      'pageRank': 0.0009117002541455947,
#      'prbConfidence': 0.01722912578098618,
#      'linPr': 0.3569739952718676,
#      'linkProb': 0.003690036900369004,
#      'logLinkProb': 0.2320884776820777},
#     {'title': '장수',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%9e%a5%ec%88%98',
#      'cosine': -99,
#      'linkCount': 2,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q12614547'},
#     {'title': '타수',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%83%80%ec%88%98',
#      'cosine': 0,
#      'linkCount': 1,
#      'pageRank': 0.002800690222204714,
#      'prbConfidence': 0.05292687359966149,
#      'linPr': 0.7635933806146572,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '모용수',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%aa%a8%ec%9a%a9%ec%88%98',
#      'cosine': 0.00132466692243125,
#      'linkCount': 1,
#      'pageRank': 0.0009634337365542068,
#      'prbConfidence': 0.01820677459862496,
#      'linPr': 0.3853427895981087,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '제신',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%a0%9c%ec%8b%a0',
#      'cosine': 0.007804631477987095,
#      'linkCount': 1,
#      'pageRank': 0.001116852570131148,
#      'prbConfidence': 0.0211060524795404,
#      'linPr': 0.4444444444444444,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '수우미양가',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ec%9a%b0%eb%af%b8%ec%96%91%ea%b0%80',
#      'cosine': 0.01078746635127266,
#      'linkCount': 1,
#      'pageRank': 0.001281115705830932,
#      'prbConfidence': 0.02421026377407715,
#      'linPr': 0.4869976359338061,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '수필',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%98%ed%95%84',
#      'cosine': 0.006342568998470416,
#      'linkCount': 1,
#      'pageRank': 0.003146058609539173,
#      'prbConfidence': 0.05945357506662358,
#      'linPr': 0.8014184397163121,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '근구수왕',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b7%bc%ea%b5%ac%ec%88%98%ec%99%95',
#      'cosine': 0.008705752648881956,
#      'linkCount': 1,
#      'pageRank': 0.00121173767123847,
#      'prbConfidence': 0.0228991718016927,
#      'linPr': 0.4704491725768322,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '공격수',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b3%b5%ea%b2%a9%ec%88%98',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '숫자',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%ab%ec%9e%90',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '이십팔수',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%9d%b4%ec%8b%ad%ed%8c%94%ec%88%98',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 3},
#   {'wFrom': 529,
#    'wTo': 529,
#    'pageRank': 6.483351144438778e-06,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.0004982561036372695,
#    'nodeId': 3681694,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['있습니다'],
#    'candidates': [{'title': '구글',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b5%ac%ea%b8%80',
#      'cosine': 0.01959006179114767,
#      'linkCount': 1,
#      'pageRank': 0.007405576266443104,
#      'prbConfidence': 1,
#      'linPr': 0.966903073286052,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.007405576266443104,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 0}],
#  'timeTotalMs': 160.271,
#  'timeAnnotationMs': 119.191,
#  'timeBuildJsonMs': 38.375,
#  'incIdxTimestampUtc': '',
#  'fnRegIdx': 'kowiki-20200301-pages-articles-index3.bin',
#  'fnWikiData': 'wikidata-20241111-all.bin',
#  'settings': {'pageRankSqThreshold': 0.8,
#   'applyPageRankSqThreshold': True,
#   'minPMentionGivenPhrase': 0,
#   'maxMentionEntropy': -1,
#   'maxTargetsPerMention': 20,
#   'useLogLinkCounts': False,
#   'candSelectionUseLinearizedPageRank': False,
#   'candSelectionPageRankThreshold': 2,
#   'candSelectionCosineWeight': 0,
#   'candSelectionLinkCtxCosineWeight': 0,
#   'candSelectionUseLinkProb': 'no',
#   'semanticSimilarity': 'in',
#   'secondaryAnnotLanguage': 'en',
#   'minLinkFrequency': 1,
#   'minLinkRelFrequency': 0,
#   'nTopDfWordsToIgnore': 0,
#   'nWordsToIgnoreFromList': 100,
#   'extraVocabsToInclude': [],
#   'altLabelSetsToUse': []},
#  'language': 'ko'}

# %%
keywords = set()
for d in wikis['ranges']:
  for candidate in d['candidates']:
    if candidate['cosine'] > 0.05:
      keywords.add(candidate['title'])
keywords
# Out:
# {'C (프로그래밍 언어)',
#  '객체 (컴퓨터 과학)',
#  '객체 지향 프로그래밍',
#  '말 (동물)',
#  '시간',
#  '여러분 (노래)',
#  '절차적 프로그래밍',
#  '컴퓨터 프로그래밍',
#  '파이썬',
#  '프로그래밍 언어',
#  '함수',
#  '함수 (프로그래밍)',
#  '함수형 프로그래밍'}

# %% [markdown]
# #### Exercise
# 영상 간 공통 키워드를 연결하는 네트워크 그래프를 만들기
# 1. N개 유튜브 강의에 대해 대표 키워드 세트 정의
# 2. 영상 2개씩 조합하여 공통 키워드 추출
# 3. 공통 키워드가 있으면 NetworkX를 이용해 연결
# 4. 엣지 라벨로 공통 키워드 표시, 노드는 영상 제목 표시

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 1. 한글 폰트 설치 (나눔고딕)
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import networkx as nx
from itertools import combinations

# 2. Colab 런타임에 폰트 적용
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# 3. 영상별 키워드 예시
# 추출한 것으로 수정 필요!
video_keywords = {
    "영상 A": {'라듐 동위 원소',
 '레늄 동위 원소',
 '메모리 주소',
 '변수 (수학)',
 '변수 (컴퓨터 과학)',
 '송공 어',
'절차적 프로그래밍',
 '컴퓨터 프로그래밍',
 '자 (도구)',
 '제88회 아카데미상',
 '진 문공 (어)',
 '토륨 동위 원소',
 '포인터 (프로그래밍)'},
    "영상 B": {'C (프로그래밍 언어)',
 '객체 (컴퓨터 과학)',
 '객체 지향 프로그래밍',
 '말 (동물)',
 '시간',
 '여러분 (노래)',
 '절차적 프로그래밍',
 '컴퓨터 프로그래밍',
 '파이썬',
 '프로그래밍 언어',
 '함수',
 '함수 (프로그래밍)',
 '함수형 프로그래밍'},
    "영상 C": {'객체 (컴퓨터 과학)',
 '객체 지향 프로그래밍',
 '네트워크 클래스',
 '볼륨 (컴퓨팅)',
 '생명',
 '선박',
 '속성 (컴퓨터 과학)',
 '숫자',
 '시간',
 '자 (도구)',
 '클래스 (컴퓨터 프로그래밍)',
 '프로그래밍 언어',
 '함수',
 '함수 (프로그래밍)',
 '함수형 프로그래밍',
 '허수 단위'}
,
    "영상 D": {'C (프로그래밍 언어)',
 '객체 (컴퓨터 과학)',
 '객체 지향 프로그래밍',
 '말 (동물)',
 '시간',
 '여러분 (노래)',
 '절차적 프로그래밍',
 '컴퓨터 프로그래밍',
 '파이썬',
 '프로그래밍 언어',
 '함수',
 '함수 (프로그래밍)',
 '함수형 프로그래밍'},
}

# 4. NetworkX 그래프 생성
G = nx.Graph()
G.add_nodes_from(video_keywords.keys())

for vid1, vid2 in combinations(video_keywords.keys(), 2):
    shared = video_keywords[vid1] & video_keywords[vid2]
    if shared:
        G.add_edge(vid1, vid2, weight=len(shared), label=", ".join(shared))

# 5. 시각화
pos = nx.spring_layout(G, seed=42)

plt.figure(figsize=(20, 15))
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color="lightyellow")
nx.draw_networkx_labels(G, pos, font_size=12, font_family='NanumBarunGothic')
nx.draw_networkx_edges(G, pos, width=2)

# edge label 표시
edge_labels = nx.get_edge_attributes(G, "label")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10, font_family='NanumBarunGothic')

plt.title("유튜브 영상 간 공통 키워드 네트워크 ", fontsize=14)
plt.axis("off")
plt.show()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
